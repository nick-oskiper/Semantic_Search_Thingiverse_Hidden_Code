# %%
# def main(num_target_models=100, top_k=10, similarity_thresholds=np.linspace(0, 1, 101)):
#     """
#     Main function to orchestrate the benchmarking process.
#     """
#     print("Starting benchmarking process...")
# 
#     graph_db = connect_to_neo4j(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
# 
#     df = fetch_all_models(graph_db, node_label="Model", vector_property="embedding")
# 
#     target_models = select_target_models(df, num_targets=num_target_models)
# 
#     print("Loading SentenceTransformer model...")
#     model = SentenceTransformer('all-MiniLM-L6-v2')
#     print("SentenceTransformer model loaded.")
# 
#     metrics_df = benchmark_similarity_thresholds(
#         df=df,
#         target_models=target_models,
#         model=model,
#         top_k=top_k,
#         thresholds=similarity_thresholds
#     )
# 
#     plot_performance_metrics(metrics_df)
# 
#     optimal_row = metrics_df.loc[metrics_df['F1-Score'].idxmax()]
#     optimal_threshold = optimal_row['Threshold']
#     print(f"Optimal Threshold based on highest F1-Score: {optimal_threshold:.4f}")
# 
#     print("\nBenchmarking Performance Metrics")
#     print(metrics_df.to_string(index=False))
#     metrics_df.to_csv("benchmark_performance_metrics.csv", index=False)
#     print("Benchmarking metrics saved to 'benchmark_performance_metrics.csv'.")
# 
# 
#     print("Benchmarking process complete.")
# 
# if __name__ == "__main__":
#     main(num_target_models=100, top_k=10, similarity_thresholds=np.linspace(0, 1, 101))
# 
# 
#
# Out:
# C:\Users\noski\PycharmProjects\Semantic_Search_Thingiverse\.venv\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\noski\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\noski\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Starting benchmarking process...
# Successfully connected to Neo4j.
# Fetching all models and their embeddings from Neo4j...
# Fetched 539 models with embeddings.
# Selecting 100 target models for benchmarking...
# Selected 100 target models.
# Loading SentenceTransformer model...
# ...

# %% [markdown]
# Notes:
# Low Thresholds (0.0 to 0.25):
# High Recall (1.0): All relevant models are retrieved.
# Low Precision (~0.018 to ~0.02): Most retrieved models are irrelevant.
# Implication: Overly broad retrieval, leading to user overwhelm with irrelevant results.
# Mid Thresholds (0.25 to 0.47):
# Balanced Precision and Recall: Precision improves while maintaining reasonable Recall.
# High F1-Score: Indicates efficient retrieval performance.
# Implication: Effective for scenarios where both comprehensive retrieval and relevance are important.
# High Thresholds (0.47 to 1.0):
# High Precision (~0.6950 to 0.0): Most retrieved models are relevant.
# Low Recall (~0.6990 to 0.0): Many relevant models are missed.
# Implication: Suitable for use-cases prioritizing relevance over comprehensiveness, but risks missing out on relevant models.
