# %% [markdown]
# All code was hidden but the main benchmark function. Outputs remain.

# %%
# def benchmark_relevance(num_trials=100, num_queries_per_model=1, max_related=15, top_k=30, threshold=0.5):
#     """
#     Benchmark the search method by evaluating its relevance against target sets.
#     """
#     logging.info("Starting Relevancy Benchmarking...")
# 
#     graph_db = connect_to_neo4j(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
# 
#     logging.info("Loading SentenceTransformer model...")
#     model = SentenceTransformer('all-MiniLM-L6-v2')
#     logging.info("SentenceTransformer model loaded successfully.")
# 
#     df_models = fetch_all_models(graph_db, model)
# 
#     similarity_categories = [
#         'SIMILAR_TAGS_NONAI',
#         'SIMILAR_TAGS_AI',
#         'SIMILAR_SUMMARY_NONAI',
#         'SIMILAR_SUMMARY_AI',
#         'SIMILAR_EMBEDDING_NONAI',
#         'SIMILAR_EMBEDDING_AI',
#         'SIMILAR_NAMES'
#     ]
# 
#     logging.info("Creating target sets for benchmarking...")
#     target_sets = {}
#     for sim_cat in similarity_categories:
#         logging.info(f"Creating target sets for {sim_cat}...")
#         target_sets[sim_cat] = create_target_sets(df_models, sim_cat, model)
#     logging.info("Completed creating target sets.")
# 
#     if 'important_word' in df_models.columns:
#         df_models.drop(columns=['important_word'], inplace=True)
# 
#     evaluation_metrics = {sim_cat: {'TP': 0, 'FP': 0, 'FN': 0, 'TN': 0} for sim_cat in similarity_categories}
# 
#     all_model_ids = set(df_models['id'])
# 
#     search_results = []
# 
#     for sim_cat in similarity_categories:
#         logging.info(f"Evaluating similarity category: {sim_cat}")
#         target_set = target_sets[sim_cat]
#         for idx, row in tqdm(df_models.iterrows(), total=df_models.shape[0], desc=f"Processing {sim_cat}"):
#             query_id = row['id']
#             if sim_cat == 'SIMILAR_TAGS_NONAI':
#                 query_tags = set(tag.strip().lower() for tag in row['tags_nonai'] if tag.strip())
#                 if len(query_tags) < 2:
#                     retrieved_ids = set()
#                 else:
#                     query_summary = row['description_nonai']
#                     retrieved_ids = set(compute_similarity(
#                         query=query_summary,
#                         model=model,
#                         df_embeddings=df_models['embedding_summary_nonai'].tolist(),
#                         df_ids=df_models['id'].tolist(),
#                         top_k=top_k,
#                         threshold=threshold,
#                         min_retrieved=2
#                     ))
#             elif sim_cat == 'SIMILAR_TAGS_AI':
#                 query_tags = set(tag.strip().lower() for tag in row['tags_ai'] if tag.strip())
#                 if len(query_tags) < 2:
#                     retrieved_ids = set()
#                 else:
#                     query_summary = row['description_ai']
#                     retrieved_ids = set(compute_similarity(
#                         query=query_summary,
#                         model=model,
#                         df_embeddings=df_models['embedding_summary_ai'].tolist(),
#                         df_ids=df_models['id'].tolist(),
#                         top_k=top_k,
#                         threshold=threshold,
#                         min_retrieved=2
#                     ))
#             elif sim_cat == 'SIMILAR_SUMMARY_NONAI':
#                 query_summary = row['description_nonai']
#                 if not query_summary.strip():
#                     retrieved_ids = set()
#                 else:
#                     retrieved_ids = set(compute_similarity(
#                         query=query_summary,
#                         model=model,
#                         df_embeddings=df_models['embedding_summary_nonai'].tolist(),
#                         df_ids=df_models['id'].tolist(),
#                         top_k=top_k,
#                         threshold=threshold,
#                         min_retrieved=2
#                     ))
#             elif sim_cat == 'SIMILAR_SUMMARY_AI':
#                 query_summary = row['description_ai']
#                 if not query_summary.strip():
#                     retrieved_ids = set()
#                 else:
#                     retrieved_ids = set(compute_similarity(
#                         query=query_summary,
#                         model=model,
#                         df_embeddings=df_models['embedding_summary_ai'].tolist(),
#                         df_ids=df_models['id'].tolist(),
#                         top_k=top_k,
#                         threshold=threshold,
#                         min_retrieved=2
#                     ))
#             elif sim_cat == 'SIMILAR_EMBEDDING_NONAI':
#                 query_embedding = row['embedding']
#                 if query_embedding.size == 0:
#                     retrieved_ids = set()
#                 else:
#                     model_embeddings = np.vstack(df_models['embedding'].tolist())
#                     similarities = compute_cosine_similarity(query_embedding, model_embeddings)
#                     top_indices = similarities.argsort()[-top_k:][::-1]
#                     retrieved_ids = set(df_models['id'].iloc[top_indices][similarities[top_indices] >= threshold])
#                     if len(retrieved_ids) < 2:
#                         relaxed_threshold = threshold * 0.8
#                         additional_ids = set(df_models['id'].iloc[top_indices][similarities[top_indices] >= relaxed_threshold]) - retrieved_ids
#                         retrieved_ids.update(list(additional_ids)[:2 - len(retrieved_ids)])
#             elif sim_cat == 'SIMILAR_EMBEDDING_AI':
#                 query_embedding = row['embedding']
#                 if query_embedding.size == 0:
#                     retrieved_ids = set()
#                 else:
#                     model_embeddings = np.vstack(df_models['embedding'].tolist())
#                     similarities = compute_cosine_similarity(query_embedding, model_embeddings)
#                     top_indices = similarities.argsort()[-top_k:][::-1]
#                     retrieved_ids = set(df_models['id'].iloc[top_indices][similarities[top_indices] >= threshold])
#                     if len(retrieved_ids) < 2:
#                         relaxed_threshold = threshold * 0.8
#                         additional_ids = set(df_models['id'].iloc[top_indices][similarities[top_indices] >= relaxed_threshold]) - retrieved_ids
#                         retrieved_ids.update(list(additional_ids)[:2 - len(retrieved_ids)])
#             elif sim_cat == 'SIMILAR_NAMES':
#                 query_name = row['name'].strip().lower()
#                 if not query_name:
#                     retrieved_ids = set()
#                 else:
#                     retrieved_ids = set(compute_similarity(
#                         query=query_name,
#                         model=model,
#                         df_embeddings=df_models['name_embedding'].tolist(),
#                         df_ids=df_models['id'].tolist(),
#                         top_k=top_k,
#                         threshold=threshold,
#                         min_retrieved=2
#                     ))
#             else:
#                 logging.warning(f"Unknown similarity category: {sim_cat}")
#                 retrieved_ids = set()
# 
#             target_ids = target_set.get(query_id, set())
#             retrieved_ids = retrieved_ids - {query_id}
#             evaluation = evaluate_retrieval(query_id, retrieved_ids, target_ids, all_model_ids)
# 
#             evaluation_metrics[sim_cat]['TP'] += evaluation['TP']
#             evaluation_metrics[sim_cat]['FP'] += evaluation['FP']
#             evaluation_metrics[sim_cat]['FN'] += evaluation['FN']
#             evaluation_metrics[sim_cat]['TN'] += evaluation['TN']
# 
#             search_results.append({
#                 "query": row['description_nonai'] if sim_cat in ['SIMILAR_TAGS_NONAI', 'SIMILAR_SUMMARY_NONAI', 'SIMILAR_EMBEDDING_NONAI'] else row['description_ai'] if sim_cat in ['SIMILAR_TAGS_AI', 'SIMILAR_SUMMARY_AI', 'SIMILAR_EMBEDDING_AI'] else row['name'],
#                 "target_ids": list(target_ids),
#                 "retrieved_ids": list(retrieved_ids)
#             })
# 
#     logging.info("Computing evaluation metrics for each similarity category...")
#     metrics_results = {}
#     for sim_cat, counts in evaluation_metrics.items():
#         metrics = compute_metrics(counts)
#         metrics_results[sim_cat] = metrics
# 
#     df_metrics = pd.DataFrame(metrics_results).T
#     df_metrics = df_metrics[['Precision', 'Recall', 'F1-Score', 'Accuracy']]
# 
#     print("\nRelevancy Benchmarking Results\n")
#     print(df_metrics.round(4))
#     print("\nDetailed Metrics\n")
#     for sim_cat, metrics in metrics_results.items():
#         print(f"Similarity Category: {sim_cat}")
#         print(f"  Precision: {metrics['Precision']:.4f}")
#         print(f"  Recall:    {metrics['Recall']:.4f}")
#         print(f"  F1-Score:  {metrics['F1-Score']:.4f}")
#         print(f"  Accuracy:  {metrics['Accuracy']:.4f}\n")
# 
#     plot_metrics_distribution(search_results=search_results)
# 
#     logging.info("Relevancy Benchmarking completed successfully.")
# Out:
# C:\Users\noski\PycharmProjects\Semantic_Search_Thingiverse\.venv\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2024-12-03 10:59:04,208 [INFO] SpaCy Pipeline Components: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# 2024-12-03 10:59:04,213 [INFO] Use pytorch device_name: cpu
# 2024-12-03 10:59:04,213 [INFO] Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# 2024-12-03 10:59:06,107 [INFO] Starting Relevancy Benchmarking...
# ...
